# %% [markdown]
# ### Q1

# %%
question = ['Q2', 'Q3', 'Q4', 'Q5', 'Q6_1', 'Q6_2', 'Q6_3', 'Q6_4', 'Q6_5', 'Q6_6',
  'Q6_7', 'Q6_8', 'Q6_9', 'Q6_10', 'Q6_11', 'Q6_12', 'Q7_1', 'Q7_2',
  'Q7_3', 'Q7_4', 'Q7_5', 'Q7_6', 'Q7_7', 'Q8', 'Q9', 'Q10_1', 'Q10_2',
  'Q10_3']

result  = []
for q in question:
  if not '_' in q:
    result.append(q)

print(result)
# Out:
# ['Q2', 'Q3', 'Q4', 'Q5', 'Q8', 'Q9']

# %% [markdown]
# ### Q2

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/healthexp.csv")

df = df.query('Year >= 2011 and Year <= 2020')
df = df.drop(["Spending_USD"], axis=1)
df = df.groupby(["Year", "Country"]).mean().unstack()
df
# Out:
#         Life_Expectancy
# Country          Canada France Germany Great Britain Japan   USA
# Year
# 2011               81.4   82.3    80.5          81.0  82.7  78.7
# 2012               81.6   82.1    80.6          81.0  83.2  78.8
# 2013               81.7   82.3    80.6          81.1  83.4  78.8
# 2014               81.8   82.8    81.2          81.4  83.7  78.9
# 2015               81.9   82.4    80.7          81.0  83.9  78.7
# 2016               82.0   82.7    81.0          81.2  84.1  78.7
# 2017               81.9   82.7    81.1          81.3  84.2  78.6
# 2018               82.0   82.8    81.0          81.3  84.3  78.7
# 2019               82.2   82.9    81.3          81.4  84.4  78.8
# 2020               81.7   82.3    81.1          80.4  84.7  77.0

# %% [markdown]
# ### Q3

# %% [markdown]
# ### Q4

# %%
from glob import glob
import pandas as pd

glob("../data/*")
file_name = glob("../data/*.csv")[0]
df = pd.read_csv(file_name, encoding="cp949")
df
# Out:
#        구분    도로종류  사고(건)  사망(명)  부상(명)
# 0   2017년    일반국도    363     19    698
# 1   2017년     지방도    230     10    451
# 2   2017년  특별광역시도    590     12   1189
# 3   2017년      시도    577     11   1125
# 4   2017년      군도    101      3    169
# 5   2017년    고속국도    120     22    273
# 6   2017년      기타     21      0     41
# 7   2018년    일반국도    249     18    487
# 8   2018년     지방도    170     11    359
# 9   2018년  특별광역시도    329      4    710
# 10  2018년      시도    355      2    698
# 11  2018년      군도     71      1    115
# 12  2018년    고속국도    104     16    211
# 13  2018년      기타     30      1     76
# 14  2019년    일반국도    498     29    964
# 15  2019년     지방도    300     18    587
# 16  2019년  특별광역시도    825      7   1594
# 17  2019년      시도    876     17   1629
# 18  2019년      군도    116      8    184
# 19  2019년    고속국도    147     20    296
# 20  2019년      기타    125      2    206

# %%
# 한글 깨짐 현상 방지
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rc('font', family="NanumGothic")
mpl.rc('axes', unicode_minus=False)

# %%
# 년도별 사고/사망/부상 건수 통계 (2017-2019)
df.groupby(["구분"]).sum().plot.bar()
# Out:
# <Axes: xlabel='구분'>

# %% [markdown]
# #### 이외에 풀 수 있는 문제
# * 년도별 사고/사망/부상 건수 통계 (2017-2019)
# * 도로종류별 사고, 사망, 부상 건수 확인 (2017-2019 합계)
# * 년도별 / 도로종류별 사고, 사망, 부상 건수 확인
