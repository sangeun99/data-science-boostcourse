# %% [markdown]
# # Q1

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %%
df_pharmacy = df[df["상권업종소분류명"] == "약국"].copy()
df_pharmacy["시도명"].value_counts()
# Out:
# 시도명
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# Name: count, dtype: int64

# %% [markdown]
# # Q2

# %%
df_animal_hospital = df[df["상권업종소분류명"] == "동물병원"]
df_animal_hospital["시도명"].value_counts()
# Out:
# 시도명
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 대전광역시       77
# 전라남도        77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# Name: count, dtype: int64

# %%
df_seoul_dermatology = df[(df["상권업종소분류명"].str.contains("피부|성형")) & (df["시도명"] == "서울특별시")]
df_seoul_dermatology["시군구명"].value_counts()
# Out:
# 시군구명
# 강남구     603
# 서초구     200
# 송파구      48
# 마포구      40
# 영등포구     39
# 강서구      38
# 광진구      37
# 강동구      37
# 중구       31
# 은평구      31
# 서대문구     29
# 성북구      28
# 동대문구     27
# 양천구      26
# 노원구      26
# 중랑구      21
# 성동구      17
# 구로구      17
# 관악구      17
# 동작구      14
# 강북구      12
# 종로구      11
# 용산구      10
# 금천구       9
# 도봉구       5
# Name: count, dtype: int64

# %%
df_seoul = df[df["시도명"] == "서울특별시"]
df_seoul["시군구명"].value_counts()
# Out:
# 시군구명
# 강남구     3120
# 서초구     1491
# 동대문구    1152
# 송파구     1021
# 광진구      935
# 강서구      799
# 노원구      741
# 은평구      739
# 영등포구     731
# 성북구      708
# 강동구      703
# 마포구      649
# 관악구      578
# 중구       576
# 양천구      574
# 서대문구     543
# 중랑구      497
# 종로구      492
# 동작구      489
# 성동구      482
# 구로구      451
# 도봉구      412
# 강북구      396
# 용산구      361
# 금천구      303
# Name: count, dtype: int64

# %%
(df_seoul_dermatology["시군구명"].value_counts() / df_seoul["시군구명"].value_counts()).round(2)
# Out:
# 시군구명
# 강남구     0.19
# 강동구     0.05
# 강북구     0.03
# 강서구     0.05
# 관악구     0.03
# 광진구     0.04
# 구로구     0.04
# 금천구     0.03
# 노원구     0.04
# 도봉구     0.01
# 동대문구    0.02
# 동작구     0.03
# 마포구     0.06
# 서대문구    0.05
# 서초구     0.13
# 성동구     0.04
# 성북구     0.04
# 송파구     0.05
# 양천구     0.05
# 영등포구    0.05
# 용산구     0.03
# 은평구     0.04
# 종로구     0.02
# 중구      0.05
# 중랑구     0.04
# Name: count, dtype: float64

# %% [markdown]
# # Q4

# %%
import folium

df_geriatric_hospital = df[df["상권업종소분류명"] == "노인/치매병원"]
df_geriatric_hospital
# Out:
#          상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 21     21128898     다사랑요양병원  NaN         S       의료       S01       병원
# 62     21511155         노경회  NaN         S       의료       S01       병원
# 69     21406385   일산카네이션너싱홈  NaN         S       의료       S01       병원
# 79     21403242       은성복지회  NaN         S       의료       S01       병원
# 107    21722929       하은실버홈  NaN         S       의료       S01       병원
# ...         ...         ...  ...       ...      ...       ...      ...
# 91184  16311246  유성재단유성요양병원  NaN         S       의료       S01       병원
# 91216  16122998   실로암요양병원매점  NaN         S       의료       S01       병원
# 91253  16108794     한사랑요양병원  NaN         S       의료       S01       병원
# 91328  16198812       서울플러스  NaN         S       의료       S01       병원
# 91332  16127538     참좋은요양병원  NaN         S       의료       S01       병원
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호        건물명  \
# 21       S01B17  노인/치매병원   Q86102  ...  2632010300101360002000001    다사랑요양병원
# 62       S01B17  노인/치매병원   Q86102  ...  4623035023110240001000001        NaN
# 69       S01B17  노인/치매병원   Q86102  ...  4128510200115610001011448     해태쇼핑타운
# 79       S01B17  노인/치매병원   Q86102  ...  4615010800200220000080503      향림실버빌
# 107      S01B17  노인/치매병원   Q86102  ...  4725033022107880000027997        NaN
# ...         ...      ...      ...  ...                        ...        ...
# 91184    S01B17  노인/치매병원   Q86102  ...  4833010400104910005003855       외한은행
# 91216    S01B17  노인/치매병원   Q86102  ...  4514012200102240004078939    실로암사랑병원
# 91253    S01B17  노인/치매병원   Q86102  ...  2917011500109670002002194        NaN
# 91328    S01B17  노인/치매병원   Q86102  ...  4420025328105080000002698  배방자이1차아파트
# 91332    S01B17  노인/치매병원   Q86102  ...  2641010800105380001005572      한신시티빌
#
#                            도로명주소     구우편번호    신우편번호  동정보  층정보  호정보  \
# 21              부산광역시 북구 덕천로 339  616110.0  46610.0  NaN    1  NaN
# 62            전라남도 광양시 진월면 용소길 7  545851.0  57713.0  NaN    1  NaN
# 69          경기도 고양시 일산동구 중산로 241  410831.0  10336.0  NaN    3  NaN
# 79              전라남도 순천시 조비길 298  540950.0  57922.0  NaN  NaN  NaN
# 107    경상북도 상주시 낙동면 영남제일로 125-17  742951.0  37251.0  NaN    2  NaN
# ...                          ...       ...      ...  ...  ...  ...
# 91184            경상남도 양산시 삼일로 75  626800.0  50619.0  NaN  NaN  NaN
# 91216           전라북도 익산시 선화로 389  570979.0  54629.0  NaN  NaN  NaN
# 91253           광주광역시 북구 서하로 244  500838.0  61130.0  NaN  NaN  NaN
# 91328       충청남도 아산시 배방읍 호서로 460  336729.0  31495.0  NaN    2  NaN
# 91332          부산광역시 금정구 금강로 209  609841.0  46294.0  NaN    2  NaN
#
#                경도         위도
# 21     129.040773  35.209154
# 62     127.746981  34.986585
# 69     126.780122  37.693689
# 79     127.460606  34.991014
# 107    128.295524  36.365132
# ...           ...        ...
# 91184  129.035645  35.343927
# 91216  126.973450  35.946242
# 91253  126.907230  35.186972
# 91328  127.083401  36.768332
# 91332  129.082790  35.227138
#
# [1055 rows x 39 columns]

# %%
map = folium.Map(location=[df_geriatric_hospital["위도"].mean(), df_geriatric_hospital["경도"].mean()])

# %%
for n in df_geriatric_hospital.index:
    name = df_geriatric_hospital.loc[n, "상호명"]
    address = df_geriatric_hospital.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [df_geriatric_hospital.loc[n, "위도"], df_geriatric_hospital.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbb0933909d8f1e521bdb5cc98ded4ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbb0933909d8f1e521bdb5cc98ded4ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbb0933909d8f1e521bdb5cc98ded4ae = L.map(
#                 &quot;map_bbb0933909d8f1e521bdb5cc98ded4ae&quot;,
#                 {
#                     center: [36.322638410225366, 127.69216156637984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c91f8c71cb0d84a5b5e6b68109303dd1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#             var marker_0c2fd91aeefe1a7f3193464b6acfd26f = L.marker(
#                 [35.2091539574761, 129.040772964856],
#                 {}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#         var popup_fb01ee5acfd683c4e905cdf2c0441272 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4a9410e7d2b987bc9b3e8887ab34d6c = $(`&lt;div id=&quot;html_e4a9410e7d2b987bc9b3e8887ab34d6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;다사랑요양병원-부산광역시 북구 덕천로 339&lt;/div&gt;`)[0];
#                 popup_fb01ee5acfd683c4e905cdf2c0441272.setContent(html_e4a9410e7d2b987bc9b3e8887ab34d6c);
#
#
#
#         marker_0c2fd91aeefe1a7f3193464b6acfd26f.bindPopup(popup_fb01ee5acfd683c4e905cdf2c0441272)
#         ;
#
#
#
#
#             var marker_5167e04a4566d447fef7d056cdd57170 = L.marker(
#                 [34.9865848568725, 127.746980976467],
#                 {}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#         var popup_a9aa8f45ae7042d32a66a38a147a5d19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f244eee51dd39b9dcf7f576010ffd9f = $(`&lt;div id=&quot;html_3f244eee51dd39b9dcf7f576010ffd9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노경회-전라남도 광양시 진월면 용소길 7&lt;/div&gt;`)[0];
#                 popup_a9aa8f45ae7042d32a66a38a147a5d19.setContent(html_3f244eee51dd39b9dcf7f576010ffd9f);
#
#
#
#         marker_5167e04a4566d447fef7d056cdd57170.bindPopup(popup_a9aa8f45ae7042d32a66a38a147a5d19)
#         ;
#
#
#
#
#             var marker_1a93317dafd9add8c9fb95822f567c67 = L.marker(
#                 [37.6936890859817, 126.780121523366],
#                 {}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#         var popup_c0e4e6d125e6fb8dcd7aa3c912439aec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d1946224594a6a475d18241da6b8032 = $(`&lt;div id=&quot;html_6d1946224594a6a475d18241da6b8032&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일산카네이션너싱홈-경기도 고양시 일산동구 중산로 241&lt;/div&gt;`)[0];
#                 popup_c0e4e6d125e6fb8dcd7aa3c912439aec.setContent(html_6d1946224594a6a475d18241da6b8032);
#
#
#
#         marker_1a93317dafd9add8c9fb95822f567c67.bindPopup(popup_c0e4e6d125e6fb8dcd7aa3c912439aec)
#         ;
#
#
#
#
#             var marker_ce811f55ad97aef83b68c6ea0a6c18af = L.marker(
#                 [34.9910140897983, 127.460606294325],
#                 {}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#         var popup_f13dec4789652af9c283b9fb5e4b31f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25a4e6a669a25dbf918baa090331425d = $(`&lt;div id=&quot;html_25a4e6a669a25dbf918baa090331425d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;은성복지회-전라남도 순천시 조비길 298&lt;/div&gt;`)[0];
#                 popup_f13dec4789652af9c283b9fb5e4b31f8.setContent(html_25a4e6a669a25dbf918baa090331425d);
#
#
#
#         marker_ce811f55ad97aef83b68c6ea0a6c18af.bindPopup(popup_f13dec4789652af9c283b9fb5e4b31f8)
#         ;
#
#
#
#
#             var marker_6864ff0d5eb892655da4f9ff764f9cf1 = L.marker(
#                 [36.3651320905281, 128.295523973833],
#                 {}
#             ).addTo(map_bbb0933909d8f1e521bdb5cc98ded4ae);
#
#
#         var popup_9327d4b6ac80ecdc68664531de64be05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1d8a6f8b6eac7740acf79a1b3a8808c = $(`&lt;div id=&quot;html_c1d8a6f8b6eac7740acf79a1b3a8808c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;하은실버홈-경상북도 상주시 낙동면 영남제일로 125-17&lt;/div&gt;`)[0];
#                 popup_9327d4b6ac80ecdc68664531de64be05.setContent(html_c1d8a6f8b6eac7740acf79a1b3a8808c);
#
#
#
#         marker_6864ff0d5eb892655da4f9ff764f9cf1.bindPopup(popup_9327d4b6ac80ecdc68664531de64be05)
